# %% [markdown]
# # Margin analysis
# Analysis to see wich products have the higest margin and the lowest. The goal of this research is to upselling the product with the highest margin to ivrease the profit of the buisinnes.

# %%
import pandas as pd
import xlrd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# xls = pd.ExcelFile('Margin VLOOKUP.xlsx')
# day = pd.read_excel(xls,'TABLE', index_col= None, skiprows = 0, nrows=8000,usecols='A:E')
# day = day.set_index('Description')
#
#
# quantity = day.sort_values(by = 'Margin', axis =0, ascending= False, na_position= "last")
# #df  = pd.DataFrame(dict_)
# quantity= quantity.query('Margin < 1')
# #quantity= quantity.dropna
# quantity= quantity.head(10)['Margin']
# quantity= quantity.astype(float).map("{:.2%}".format)
# print("Top 10 margin")
#
# #print(quantity)
#
# print("---------------------------------------------------------")
#
# quantity = day.sort_values(by = 'Margin', axis =0, ascending= True, na_position= "last")
# #df  = pd.DataFrame(dict_)
# #quantity= quantity.query('Margin < 1')
# #quantity= quantity.dropna
# quantity= quantity.head(10)['Margin']
# quantity= quantity.astype(float).map("{:.2%}".format)
# print("Worst 10 margin")
# #print(quantity)
#
# print("---------------------------------------------------------")
#
# #print(day)

# %%
group=day.loc[day["Group"]== "D01 - Fresh"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= False, na_position= "last")
#df  = pd.DataFrame(dict_)
group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Top 10 D01 - Fresh")

print(group)

print("---------------------------------------------------------")
group=day.loc[day["Group"]== "D01 - Fresh"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= True, na_position= "last")
#df  = pd.DataFrame(dict_)
#group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Worst 10 D01 - Fresh")

print(group)

print("---------------------------------------------------------")
# Out:
# Top 10 D01 - Fresh
# Description
# T/A DIGEST TEA           97.00%
# T/A CLARITY TEA          97.00%
# T/A MORROCAN MINT TEA    96.70%
# T/A EARL GREY CITRUS     96.70%
# T/A SPIRIT AND LEMON     96.70%
# T/A SPIRIT TEA           96.70%
# T/A DREAMTIME TEA        96.70%
# BABYCCINO T/A            96.40%
# T/A RADIANCE TEA         96.10%
# T/A DRAGONWELL TEA       95.50%
# Name: Margin, dtype: object
# ---------------------------------------------------------
# Worst 10 D01 - Fresh
# Description
# PEA SHOOTS PUNNET                    -239.20%
# DO BRANDY BUTTER                     -126.00%
# DO FRUIT JELLIES                      -70.06%
# STRAWBERRIES P                        -55.82%
# DO CHOCOLATE COCONUT MARSHMALLOWS     -52.80%
# DO GINGER STAR BISCUITS               -52.00%
# DPS WHITE CHOC ROCKY ROAD             -51.20%
# DO FRUIT & NUT BRITTLE                -51.20%
# DO PRALINE MERINGUES                  -49.60%
# DO HONEYCOMB ROCKY ROAD               -48.80%
# ...

# %%
group=day.loc[day["Group"]== "D02 - Ambient"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= False, na_position= "last")
#df  = pd.DataFrame(dict_)
group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Top D02 - Ambient")

print(group)

print("---------------------------------------------------------")
group=day.loc[day["Group"]== "D02 - Ambient"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= True, na_position= "last")
#df  = pd.DataFrame(dict_)
#group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Worst 10D02 - Ambient")

print(group)

print("---------------------------------------------------------")
# Out:
# Top D02 - Ambient
# Description
# DO SMALL CHRISTMAS PUDDING 450G     93.74%
# DF SPARKLING WATER 500ML            89.44%
# DF WATER 500ML STILL                89.44%
# DAYLESFORD SPARKLING WATER 1.5L     85.54%
# DAYLESFORD STILL WATER 1.5L         85.54%
# ORG BULK DRIED APRICOTS WHOLE       84.56%
# DAYLESFORD STILL WATER              83.20%
# DO WHITE PEONY TEA CADDY            82.73%
# DAYLESFORD SPARKLING WATER 330ML    82.60%
# DO COCONUT MILK                     80.42%
# Name: Margin, dtype: object
# ---------------------------------------------------------
# Worst 10D02 - Ambient
# Description
# DN SHOWSTOPPER LEGBAR HEN              -53.88%
# DO RAW VEGAN EGGS                      -52.60%
# DN ROSE CREAMS                         -52.28%
# DN VIOLET CREAMS                       -52.28%
# CHOC COVERED CANDIED FRUIT SEL         -51.50%
# DARK CHOCOLATE & GINGER DATES          -45.05%
# DN MILK CHOC EGG SLAB WT BUNNY         -42.56%
# ...

# %%
group=day.loc[day["Group"]== "D03 - Wines & Spirits"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= False, na_position= "last")
#df  = pd.DataFrame(dict_)
group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Top D02 D03 - Wines & Spirits")

print(group)

print("---------------------------------------------------------")
group=day.loc[day["Group"]== "D03 - Wines & Spirits"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= True, na_position= "last")
#df  = pd.DataFrame(dict_)
#group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Worst 10 D03 - Wines & Spirits")

print(group)

print("---------------------------------------------------------")
# Out:
# Top D02 D03 - Wines & Spirits
# Description
# BTL NOVAS CAB MERLOT                 72.30%
# BOBBY BEER PINT SF                   69.10%
# YUBBY PINT SF                        66.40%
# DO DAYLESFORD ROSSO DOC              64.33%
# DO DAYLESFORD FALERIO DOC            63.42%
# LEGATO INZOLIA IGT SICILIA           60.76%
# COL HOUSE MULLED CIDER               60.00%
# DO LEOUBE ROSE PROMOTION SKU         58.59%
# COPENHAGEN ORG SPARKLING TEA PINK    56.84%
# MONT'ALBANO MERLOT REFOSCO           55.60%
# Name: Margin, dtype: object
# ---------------------------------------------------------
# Worst 10 D03 - Wines & Spirits
# Description
# LEOUBE SPARK ROSE 1/2 BOTTLE 37.5CL    0.00%
# ORG ALE P                              0.00%
# TEST PRODUCTPROMOEDIT                  0.00%
# DO GOLDEN FLEECE BARREL                0.00%
# DN BROWN BULL BARREL                   0.00%
# YUBBY BARREL SF                        0.00%
# CIDER DMG                              0.00%
# ...

# %%
group=day.loc[day["Group"]== "D08 - Home"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= False, na_position= "last")
#df  = pd.DataFrame(dict_)
group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Top 10 D08 - Home")

print(group)

print("---------------------------------------------------------")
group=day.loc[day["Group"]== "D08 - Home"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= True, na_position= "last")
#df  = pd.DataFrame(dict_)
#group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Worst 10  D08 - Home")

print(group)

print("---------------------------------------------------------")
# Out:
# Top 10 D08 - Home
# Description
# DF MARBLE HEART 20 X 2CM             88.30%
# IRON NAIL 6.4CM                      87.52%
# JASPER TEALIGHT HOLDER LARGE         86.75%
# DF WHIPPET WINE COOLER               85.74%
# IRON NAIL 12CM                       84.71%
# IRON NAIL 8CM                        84.71%
# JASPER TEALIGHT HOLDER SMALL         84.10%
# DF WHITE AND NATURAL NAPKIN 55X55    83.87%
# DF GREEN AND WHITE NAPKIN 55X55      83.87%
# DF SMOKE GREEN TUMBLER 8X7.50CM      82.89%
# Name: Margin, dtype: object
# ---------------------------------------------------------
# Worst 10  D08 - Home
# Description
# B Holdings Stock Seed Magazine V2      0.00%
# DF FIRESTARTER PACK                    0.00%
# DF ARTHUR WIDE CHECK CUSH COV 45X45    0.00%
# DF ARTHUR CHECKERBOARD CUSH COV 45     0.00%
# DF ARTHUR STRIPE CUSH COV 45X45CM      0.00%
# RED MADAGASCAR 50X50 CUSH COV          0.00%
# RED MADAGASCAR 30X50 CUSH COVER        0.00%
# BLUE MADAGASCAR 50X50 CUSH COVER       0.00%
# ...

# %%
group=day.loc[day["Group"]== "D18 - Frozen"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= False, na_position= "last")
#df  = pd.DataFrame(dict_)
group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Top 10 D18 - Frozen")

print(group)

print("---------------------------------------------------------")
group=day.loc[day["Group"]== "D18 - Frozen"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= True, na_position= "last")
#df  = pd.DataFrame(dict_)
#group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Worst 10 D18 - Frozen")

print(group)

print("---------------------------------------------------------")
# Out:
# Top 10 D18 - Frozen
# Description
# LICKALIX MANGO RASPBERRY LOLLY         59.87%
# LICKALIX SIMPLY CHOCOLATE LOLLY        59.87%
# LICKALIX STRAWBERRY & LEMON LOLLY      59.87%
# MIIRO SALT CARA VEGAN ICE CREAM        46.21%
# MIIRO CHOC HAZ VEGAN ICE CREAM         46.21%
# LUSCIOUS ORG MADAGASCAN VANILLA I/C    40.83%
# LUSCIOUS ORG RICH CHOCOLATE I/C        40.83%
# LUSCIOUS ORG BANANA CUSTARD I/C        40.83%
# LUSCIOUS ORG STRAWBERRIES&CREAM I/C    40.83%
# LUSCIOUS ORG COFFEE & CREAM I/C        40.83%
# Name: Margin, dtype: object
# ---------------------------------------------------------
# Worst 10 D18 - Frozen
# Description
# IQF DICED PLUM P                   0.00%
# FROZEN ORGANIC REDCURRANTS KG P    0.00%
# DMG FROZEN BLACKCURRANTS           0.00%
# FROZEN BLACKBERRIES 10KG           0.00%
# IQF STRAWBERRIES 10KG P            0.00%
# DMG FROZEN BLACKCURRANTS P         0.00%
# AVOCADO FROZEN IQF ORG             0.00%
# CRANBERRIES FROZEN 1KG             0.00%
# ...

# %%
group=day.loc[day["Group"]== "D07 - Health & Beauty"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= False, na_position= "last")
#df  = pd.DataFrame(dict_)
group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Top 10 D07 - Health & Beauty")

print(group)

print("---------------------------------------------------------")
group=day.loc[day["Group"]== "D07 - Health & Beauty"]
group = pd.DataFrame(group)
group = group.sort_values(by = 'Margin', axis =0, ascending= True, na_position= "last")
#df  = pd.DataFrame(dict_)
#group= group.query('Margin < 1')
#quantity= quantity.dropna
group= group.head(10)['Margin']
group= group.astype(float).map("{:.2%}".format)
print("Worst 10 D07 - Health & Beauty")

print(group)

print("---------------------------------------------------------")
# Out:
# Top 10 D07 - Health & Beauty
# Description
# BMF ESSENTAIL OIL GIFT SET          50.05%
# BMF BOTANIC LIP BALM 15ML           50.03%
# B SILENT MIGHTTIME TEMPLE BALM      50.02%
# BMF BABY HAIR AND BODY WASH         50.02%
# BGD EDITION 1 FACE WASH 75ML        50.02%
# BGD SPORT DEODORANT                 50.02%
# BMF B SILENT PILLOW MIST            50.02%
# BMF GERANIUM HAND & BODY LOTION     50.02%
# BMF JASMINE HAND AND BODY LOTION    50.02%
# BMF BOTANIC BODY OIL 125ML          50.01%
# Name: Margin, dtype: object
# ---------------------------------------------------------
# Worst 10 D07 - Health & Beauty
# Description
# BMF ORGANIC BABY BALM 60G      40.00%
# BGD SPORT ARNICA BALM 60G      40.00%
# BGD SPORT WASH 250ML           40.00%
# BGD EDITION 1 COLOGNE 50ML     40.00%
# BMF BOTANIC HAND CREAM 75ml    49.98%
# BGD EDITION 1 SHAMPOO          49.98%
# BGD EDITION 1 BODY WASH        49.98%
# BGD EDITION 1 TRAVEL KIT       49.99%
# BMF BOTANIC BATH SALTS 200g    50.00%
# ...
